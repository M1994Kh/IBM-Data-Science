# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Mehran Khorasani Esmaeili</b>
# <p>I'm a Python Developer and eager to be a data scientist in the coming years.</p>

# %% [markdown]
# <i> With the expansion of the digital world, we are surrounded by an enormous cloud of wonderful data. Finding hidden relations between these data and the system that governs the world is exciting. It's like the adventures of Sherlock Holmz, and I deeply want to learn the fundamentals of this science. It would be a wonderful job to find new things that control our world behind the scene.</i>

# %% [markdown]
# <h3> This code can calculate the 2^20</h3>

# %%
2**20

# %% [markdown]
# <img src="https://d1m75rqqgidzqn.cloudfront.net/wp-data/2019/09/11134058/What-is-data-science-2.jpg">
# <h2>Data Science Lifecycle</h2>
# <hr>
# <ul>
#     <li>Business Understanding</li>
#     <li>Data Mining</li>
#     <li>Data Cleaning</li>
#     <li>Data Exploration</li>
#     <li>Feature Engineering</li>
#     <li>Predictive Modeling</li>
#     <li>Data Visualization</li>
# </ul>
